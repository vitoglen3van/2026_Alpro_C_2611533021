# %% [markdown]
# <div align ="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Algoritma dan Pemograman"**
#
# **Disusun Oleh :**
#
# **Vito Glenevan**
#
# **2611533021**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="image/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# -----------------------------------------------------------------------------------

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum ... yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan ...
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep ... pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026
#
#
# (Vito Glenevan)

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Penguasaan manipulasi data merupakan konsep mendasar dalam pemrograman sebelum melangkah ke struktur data yang lebih kompleks. Dalam bahasa pemrograman Python, data dikelompokkan ke dalam berbagai jenis tipe data dasar untuk menentukan jenis nilai yang dapat disimpan serta operasi yang dapat dilakukan terhadapnya (Python Software Foundation, 2026). Pemahaman yang mendalam mengenai variabel—sebagai wadah penyimpanan nilai di memori—serta berbagai tipe datanya seperti numerik, string, boolean, dan bentuk konstanta menjadi kunci utama dalam membangun logika program yang efisien.
#
# Selain penggunaan variabel internal, interaksi program dengan pengguna melalui perintah masukan (input) juga merupakan aspek vital dalam pengembangan perangkat lunak interaktif. Oleh karena itu, praktikum mengenai Tipe Data dan Variabel pada Pertemuan 2 mata kuliah Praktikum Struktur Data ini sangat penting untuk dilaksanakan. Praktikum ini memberikan pemahaman praktis kepada praktikan mengenai cara mendeklarasikan variabel, mengolah berbagai tipe data (termasuk konversi tipe data atau casting), menentukan nilai tetap (constant), serta menangani masukan pengguna secara langsung dalam lingkungan Visual Studio Code.
#
# ## 1.2 Tujuan
# 1. Memahami konsep penggunaan variabel serta berbagai tipe data dasar dalam Python, seperti Boolean, input, konstanta, numerik, dan string.
#
# 2. Menerapkan proses konversi tipe data (*type casting*) serta penggunaan `typing.Final` sebagai penanda konstanta dalam program Python.
#
# 3. Menganalisis hasil eksekusi program dan menjelaskan alur logika dari lima program yang menggunakan jenis tipe data yang berbeda.
#
#
# ## 1.3 Manfaat
# 1. Bagi Praktikan : Mampu mengidentifikasi tipe data yang tepat untuk penulisan variabel serta terbiasa menangani input/output pada skrip Python
#
# 2. Bagi Akademik : Sebagai bentuk evaluasi dasar kemampuan logika pemrograman mahasiswa sebelum memasuki topik struktur data bertipe majemuk seperti List, Tuple, dan Dictionary.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#  ### 1. Tipe Data Boolean
#
# Tipe data Boolean (`bool`) merupakan tipe data yang digunakan untuk menyatakan dua kondisi, yaitu `True` (benar) dan `False` (salah). Boolean banyak digunakan dalam logika pemrograman, terutama ketika program perlu menentukan apakah suatu kondisi terpenuhi atau tidak.
#
# * **Pengujian Kondisi:** Nilai Boolean biasanya diperoleh dari operasi perbandingan menggunakan operator seperti `>=`, `<=`, `==`, dan `!=`.
# * **Ekspresi Logika:** Beberapa kondisi Boolean dapat digabungkan menggunakan operator `and`, `or`, dan `not` untuk menghasilkan keputusan tertentu.
# * **Pengendalian Alur:** Boolean sering digunakan sebagai kondisi pada struktur percabangan seperti `if-else` untuk menentukan bagian program yang akan dijalankan.
#
# ### 2. Tipe Data Input dan Konversi Tipe Data (*Type Casting*)
#
# 1. Tipe Data Boolean Tipe data Boolean (`bool`) merupakan tipe data paling dasar dalam logika pemrograman yang hanya memiliki dua nilai mutlak, yaitu `True` (benar) dan `False` (salah) (Python Software Foundation, 2026).
#    - Pengujian Kondisi: Nilai boolean umumnya dihasilkan dari operasi perbandingan menggunakan operator seperti `>=`, `<=`, `==`, atau `!=`.
#    - Ekspresi Logika: Operasi logika pada boolean dapat digabungkan menggunakan operator logika seperti `and`, `or`, dan `not` untuk menent\`ukan keputusan pada alur program.
#    - Pengendalian Alur (Control Flow): Digunakan sebagai syarat utama dalam struktur percabangan (`if-else`) guna menentukan blok kode mana yang akan dieksekusi oleh sistem.
# 2. Tipe Data Input dan Konversi Tipe Data (Type Casting) Input merupakan mekanisme interaksi antara pengguna dan program untuk memasukkan data secara dinamis ke dalam memori (Microsoft, 2026).
#    - Fungsi `input()`: Digunakan untuk menerima masukan teks dari pengguna melalui terminal console.
#    - Sifat Luaran Teks (String Default): Semua nilai yang diambil melalui fungsi `input()` secara otomatis disimpan sebagai tipe data string (`str`), meskipun penguna memasukkan karakter angka.
#    - Konversi Tipe Data (Type Casting): Karena luaran `input()` berupa string, diperlukan proses konversi tipe data secara eksplisit menggunakan fungsi seperti `int()` atau `float()` agar data angka tersebut dapat dihitung dalam operasi aritmetika.
# 3. Tipe Data Konstanta (Constant) Secara bawaan (native), Python tidak memiliki fitur penentu variabel yang nilainya benar-benar terkunci mutlak sebagai konstanta seperti bahasa pemrograman lain.
#    - Konvensi Penulisan: Secara tradisional, variabel yang bernilai tetap ditandai dengan penulisan nama variabel menggunakan huruf kapital secara keseluruhan (contoh: `PI`).
#    - Penggunaan `typing.Final`: Python menyediakan modul `Final` dari pustaka bawaan `typing` untuk menegaskan secara eksplisit bahwa variabel tersebut bersifat konstan dan nilainya tidak boleh diubah sepanjang program berjalan (Python Software Foundation, 2026).
#    - Keamanan Kode: Menjaga nilai penting—seperti konstanta matematika atau konfigurasi sistem—agar tidak tidak sengaja tertimpa (overwrite) oleh baris kode lain.
# 4. Tipe Data Numerik Tipe data numerik digunakan untuk menyimpan data bertipe angka. Python mendukung tiga jenis tipe data numerik utama:
#    - `Integer` (`int`): Tipe data yang menyimpan bilangan bulat positif atau negatif tanpa koma/desimal (contoh: `100`, `-5`).
#    - `Floating-Point` (`float`): Tipe data yang menyimpan bilangan desimal atau pecahan yang ditandai dengan tanda titik (.) (contoh: `10.2345`).
#    - `Complex` (`complex`): Tipe data yang menyimpan bilangan kompleks atau imajiner, di mana bagian imajiner ditandai dengan akhiran huruf `j` (contoh: `100 + 3j`).
# 5. Tipe Data String Tipe data `String` (`str`) merupakan sekumpulan karakter yang dibentuk oleh susunan huruf, angka, simbol, atau spasi (Python Software Foundation, 2026).
#    - Petik Tunggal (`' '`) / Petik Ganda (`" "`): Digunakan untuk mendefinisikan kalimat atau teks dalam satu baris tunggal.
#    - Petik Tiga (`""" """`): Digunakan untuk mendefinisikan teks string yang spans lebih dari satu baris (multiline string), di mana format baris baru dan spasi indentasi di dalamnya tetap dipertahankan.
#    - Identifikasi Tipe Data (`type()`): Fungsi bawaan `type()` dapat digunakan untuk memeriksa jenis tipe data dari suatu variabel yang sedang diolah.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program Numeric_2611531021

# %%
#create a variable with numeric type value.
a_3021=100
print("The type of a variable having value", a_3021, " is ", type(a_3021))

#create a variable with float value.
b_3021=10.2345
print("The type of variable having value", b_3021, " is ", type(b_3021))

#create a variable with complex value.
c_3021=100+3j
print("The type of variable having value", c_3021, " is ", type(c_3021))
# Out:
# The type of a variable having value 100  is  <class 'int'>
# The type of variable having value 10.2345  is  <class 'float'>
# The type of variable having value (100+3j)  is  <class 'complex'>

# %% [markdown]
# **Penjelasan :**
# 1. Deklarasi `a_3021 = 100` sebagai tipe data Integer.
# 2. Cetak nilai `a_3021` beserta tipe datanya menggunakan fungsi `type(a_3021)`.
# 3. Deklarasi `b_3025 = 10.2345` sebagai tipe data Float.
# 4. Cetak nilai `b_3021` beserta tipe datanya menggunakan fungsi `type(b_3021)`.
# 5. Deklarasi `c_3021 = 100+3j` sebagai tipe data Complex.
# 6. Cetak nilai `c_3021` beserta tipe datanya menggunakan fungsi `type(c_3021)`.

# %% [markdown]
# ### 2.2.2 Program String_2611533021

# %%
nama = "Vito_3021"
jenis_kelamin = 'L'
alamat = """
Kampus Unand
kec.kuranji
kota Padang
"""
agama = 'islam'
print("Nama saya adalah: ", nama)
print("Jenis kelamin saya adalah: ", jenis_kelamin)
print("Alamat saya adalah: ", alamat)
print("Agama saya adalah: ", agama)
# Out:
# Nama saya adalah:  Vito_3021
# Jenis kelamin saya adalah:  L
# Alamat saya adalah:
# Kampus Unand
# kec.kuranji
# kota Padang
#
# Agama saya adalah:  islam

# %% [markdown]
# **Penjelasan :**
#
# Deklarasi nama_3021 = "Vito_3021" sebagai tipe data String.
#
# Deklarasi jenis_kelamin_3021 = 'L' sebagai tipe data String.
#
# Deklarasi alamat_3021 menggunakan petik tiga (""") sebagai tipe data String multi-baris (multiline string).
#
# Deklarasi agama_3021 = 'Islam' sebagai tipe data String.
#
# Cetak ("Nama saya adalah: ", nama_3021).
#
# Cetak ("Jenis kelamin saya adalah: ", jenis_kelamin_3021).
#
# Cetak ("Alamat saya adalah: ", alamat_3021).
#
# Cetak ("Agama saya adalah: ", agama_3021).

# %% [markdown]
# ### 2.2.3 Program Boolean_2611533021

# %%
is_lulus = True
is_cumlaude = True

nilai_3021 = 85
batas_lulus = 75

status_kelulusan = nilai_3021 >= batas_lulus #Hasilnya akan True

print("=== Check Kelulusan ===")
print("nilai:", nilai_3021)
print("Apakah Lulus?:", status_kelulusan)
if is_lulus and is_cumlaude: ''
print("Selamat, Anda lulus dengan predikat CumLaude!")
# Out:
# === Check Kelulusan ===
# nilai: 85
# Apakah Lulus?: True
# Selamat, Anda lulus dengan predikat CumLaude!

# %% [markdown]
# **Penjelasan :**
# 1. Deklarasi is_lulus = True sebagai tipe data Boolean.
#
# 2. Deklarasi is_cumlaude = True sebagai tipe data Boolean.
#
# 3. Deklarasi nilai_3021 = 85 sebagai tipe data Integer.
#
# 4. Deklarasi batas_lulus_3021 = 75 sebagai tipe data Integer.
#
# 5. Menentukan variabel status_kelulusan dari ekspresi perbandingan nilai_3021 >= batas_lulus_3021 yang menghasilkan nilai Boolean (True).
#
# 6. Cetak ("=== Check Kelulusan ===").
#
# 7. Cetak ("Nilai: ", nilai_3021).
#
# 8. Cetak ("Apakah Lulus? :", status_kelulusan).
#
# 9. Pengujian kondisi if is_lulus and is_cumlaude: untuk mengecek dua variabel Boolean sekaligus.
#
# 10. Cetak ("Selamat, Anda lulus dengan predikat Cum laude!") jika kondisi pengujian bernilai True.

# %% [markdown]
# ### 2.2.4 Program Input_2611533021

# %%
panjang_3021 = input('masukkan panjang')
lebar_3021 = input('masukkan lebar')
luas_3021 = int(panjang_3021) * int(lebar_3021)

print("Luas =, luas_3021")

# %% [markdown]
# **Penjelasan :**
# 1. Mengambil masukan nilai panjang dari pengguna dengan fungsi input() dan menyimpannya pada variabel panjang_3025 sebagai string.
#
# 2. Mengambil masukan nilai lebar dari pengguna dengan fungsi input() dan menyimpannya pada variabel lebar_3025 sebagai string.
#
# 3. Melakukan konversi tipe data (type casting) panjang_3025 dan lebar_3025 menjadi int, mengalikan keduanya, lalu menyimpannya pada variabel luas_3025.
# Cetak ("Luas =", luas_3025).

# %% [markdown]
# ### 2.2.5 Program Konstanta_2611533021

# %%
from typing import Final
PI: Final = 3.14
print("pi: %f % (PI)")
jari_3021 = float(input('8'))
luas_3021 = PI * jari_3021 * jari_3021
print("Luas lingkaran dengan jari_jari %.2f adalah %.2f % (jari_3021, luas_3021)")

# %% [markdown]
# **Penjelasan :**
# 1. Mengimpor entitas Final dari modul typing.
#
# 2. Deklarasi PI: Final = 3.14 sebagai variabel konstanta berjenis Float.
#
# 3. Cetak nilai PI dengan format bilangan desimal/float ("pi: %f" % (PI)).
#
# 4. Mengambil masukan nilai jari-jari dari pengguna dengan input(), dikonversi ke Float, lalu disimpan pada variabel jari_3021.
#
# 5. Menghitung luas lingkaran dengan rumus PI * jari_3021 * jari_3021 lalu menyimpannya pada variabel luas_3021.
#
# 6. Cetak hasil perhitungan luas lingkaran beserta jari-jarinya dengan format dua angka di belakang koma (%.2f).

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa pemahaman mengenai variabel dan tipe data merupakan salah satu dasar penting dalam pemrograman Python. Dengan memahami konsep tersebut, data dapat disimpan dan digunakan sesuai dengan kebutuhan program.
#
# Python memiliki sifat *dynamic typing*, sehingga tipe data suatu variabel dapat ditentukan secara otomatis berdasarkan nilai yang diberikan. Selain itu, fungsi `type()` dapat digunakan untuk mengetahui tipe data, sedangkan *type casting* digunakan untuk mengubah data dari satu tipe ke tipe lainnya. Melalui penggunaan berbagai tipe data seperti Boolean, Input, Constant, Numeric, dan String, program dapat mengolah dan memproses data dengan lebih tepat sesuai dengan logika yang diperlukan.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# 1. GitHub. (2026). About repositories. GitHub Docs. https://docs.github.com/en/repositories/creating-and-managing-repositories/about-repositories
#
# 2. Microsoft. (2026). Python in Visual Studio Code. Visual Studio Code Documentation. https://code.visualstudio.com/docs/languages/python
#
# 3. Python Software Foundation. (2026). Built-in Types — Python Documentation. Python Documentation. https://docs.python.org/3/library/stdtypes.html
#
# 4. Python Software Foundation. (2026). The Python Tutorial. Python Documentation. https://docs.python.org/3/tutorial/
